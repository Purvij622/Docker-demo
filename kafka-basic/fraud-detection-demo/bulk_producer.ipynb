# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers=['kafka:9092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

user_ids = [101, 102, 103, 104, 105]

tx_id = 1

for user_id in user_ids:

    for i in range(500):

        tx_data = {
            "tx_id": tx_id,
            "userId": user_id,
            "amount": random.uniform(10, 15000),
            "timestamp": time.time()
        }

        producer.send(
            "fraud-detection",
            value=tx_data
        )

        tx_id += 1

producer.flush()

print("2500 Transactions Sent")
# Out:
# 2500 Transactions Sent
