# %%
from kafka import KafkaProducer
import json 
import time 
import random
producer = KafkaProducer(
    bootstrap_servers=[' kafka: 9092'],
    value_serializer=lambda v: json. dumps (v). encode ('utf-8')
)
user_ids = [101, 102, 103, 104, 105]

print ("Starting Transaction Producer...")

for i in range (100):
    tx_data = {
        "tx_id": i,
        "userId": random.choice(user_ids),
        "amount": random.uniform(10.0, 15000.0),# >10000 triggers fraud
        "timestamp":time.time()
    }
    producer. send('fraud-detection', value=tx_data)
    print (f"Sent: {tx_data}")
    time. sleep(2)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 104, 'amount': 4941.690419936807, 'timestamp': 1781843852.590161}
# Sent: {'tx_id': 1, 'userId': 102, 'amount': 4406.017000026968, 'timestamp': 1781843854.6941245}
# Sent: {'tx_id': 2, 'userId': 101, 'amount': 7484.905423522396, 'timestamp': 1781843856.694641}
# Sent: {'tx_id': 3, 'userId': 104, 'amount': 14116.69670588909, 'timestamp': 1781843858.6973479}
# Sent: {'tx_id': 4, 'userId': 103, 'amount': 5163.2162068470825, 'timestamp': 1781843860.6978133}
# Sent: {'tx_id': 5, 'userId': 101, 'amount': 6333.887501802936, 'timestamp': 1781843862.6989377}
# Sent: {'tx_id': 6, 'userId': 105, 'amount': 9838.634467223479, 'timestamp': 1781843864.6994488}
# Sent: {'tx_id': 7, 'userId': 101, 'amount': 5984.034024088102, 'timestamp': 1781843866.702636}
# Sent: {'tx_id': 8, 'userId': 104, 'amount': 13343.294535837953, 'timestamp': 1781843868.7031896}
# Sent: {'tx_id': 9, 'userId': 101, 'amount': 873.3099750488585, 'timestamp': 1781843870.7050498}
# Sent: {'tx_id': 10, 'userId': 103, 'amount': 599.6631430693675, 'timestamp': 1781843872.7057233}
# Sent: {'tx_id': 11, 'userId': 105, 'amount': 7292.353164349517, 'timestamp': 1781843874.7071614}
# Sent: {'tx_id': 12, 'userId': 105, 'amount': 12973.191700064594, 'timestamp': 1781843876.7091575}
# Sent: {'tx_id': 13, 'userId': 102, 'amount': 1655.531107861599, 'timestamp': 1781843878.709652}
# Sent: {'tx_id': 14, 'userId': 101, 'amount': 5069.515170705305, 'timestamp': 1781843880.7110026}
# Sent: {'tx_id': 15, 'userId': 101, 'amount': 13122.084548047547, 'timestamp': 1781843882.7117062}
# Sent: {'tx_id': 16, 'userId': 102, 'amount': 4782.389405067659, 'timestamp': 1781843884.7122374}
# Sent: {'tx_id': 17, 'userId': 105, 'amount': 3230.1200798159543, 'timestamp': 1781843886.7137349}
# Sent: {'tx_id': 18, 'userId': 103, 'amount': 14027.323009806007, 'timestamp': 1781843888.714255}
# Sent: {'tx_id': 19, 'userId': 102, 'amount': 7231.632720730433, 'timestamp': 1781843890.7153523}
# Sent: {'tx_id': 20, 'userId': 103, 'amount': 9654.220876897632, 'timestamp': 1781843892.7188783}
# Sent: {'tx_id': 21, 'userId': 105, 'amount': 10915.90887455884, 'timestamp': 1781843894.719355}
# Sent: {'tx_id': 22, 'userId': 105, 'amount': 4581.6966838079625, 'timestamp': 1781843896.719848}
# Sent: {'tx_id': 23, 'userId': 102, 'amount': 6616.365519611381, 'timestamp': 1781843898.7230532}
# Sent: {'tx_id': 24, 'userId': 103, 'amount': 3025.7809473915895, 'timestamp': 1781843900.7237933}
# Sent: {'tx_id': 25, 'userId': 105, 'amount': 14267.222275151827, 'timestamp': 1781843902.7254207}
# Sent: {'tx_id': 26, 'userId': 105, 'amount': 9345.516454004797, 'timestamp': 1781843904.725873}
# Sent: {'tx_id': 27, 'userId': 105, 'amount': 14776.860995783098, 'timestamp': 1781843906.7265337}
# Sent: {'tx_id': 28, 'userId': 104, 'amount': 7193.286970180002, 'timestamp': 1781843908.727571}
# Sent: {'tx_id': 29, 'userId': 105, 'amount': 11517.522389638942, 'timestamp': 1781843910.728249}
# Sent: {'tx_id': 30, 'userId': 105, 'amount': 6428.746578207448, 'timestamp': 1781843912.7286832}
# Sent: {'tx_id': 31, 'userId': 104, 'amount': 10000.253174933454, 'timestamp': 1781843914.7310395}
# Sent: {'tx_id': 32, 'userId': 105, 'amount': 4297.361912615733, 'timestamp': 1781843916.731404}
# Sent: {'tx_id': 33, 'userId': 105, 'amount': 5726.246112258473, 'timestamp': 1781843918.7328086}
# Sent: {'tx_id': 34, 'userId': 103, 'amount': 6942.7569579814135, 'timestamp': 1781843920.7341383}
# Sent: {'tx_id': 35, 'userId': 102, 'amount': 9779.506372186746, 'timestamp': 1781843922.7357345}
# Sent: {'tx_id': 36, 'userId': 101, 'amount': 12096.716886891007, 'timestamp': 1781843924.7363849}
# Sent: {'tx_id': 37, 'userId': 104, 'amount': 2133.8095507236867, 'timestamp': 1781843926.7377408}
# Sent: {'tx_id': 38, 'userId': 103, 'amount': 1561.8235839746762, 'timestamp': 1781843928.7384617}
# Sent: {'tx_id': 39, 'userId': 103, 'amount': 14582.080403358488, 'timestamp': 1781843930.7389507}
# Sent: {'tx_id': 40, 'userId': 103, 'amount': 6797.760412235828, 'timestamp': 1781843932.7394025}
# Sent: {'tx_id': 41, 'userId': 105, 'amount': 6515.136854653555, 'timestamp': 1781843934.740807}
# Sent: {'tx_id': 42, 'userId': 102, 'amount': 1443.9058901286735, 'timestamp': 1781843936.743141}
# Sent: {'tx_id': 43, 'userId': 105, 'amount': 4227.004797936049, 'timestamp': 1781843938.7438672}
# Sent: {'tx_id': 44, 'userId': 103, 'amount': 5879.187947046423, 'timestamp': 1781843940.7449822}
# Sent: {'tx_id': 45, 'userId': 102, 'amount': 739.7686172188816, 'timestamp': 1781843942.745985}
# Sent: {'tx_id': 46, 'userId': 104, 'amount': 2183.7090047711513, 'timestamp': 1781843944.7464905}
# Sent: {'tx_id': 47, 'userId': 105, 'amount': 6038.9267525337245, 'timestamp': 1781843946.7471294}
# Sent: {'tx_id': 48, 'userId': 105, 'amount': 10465.7182906158, 'timestamp': 1781843948.7484055}
# Sent: {'tx_id': 49, 'userId': 105, 'amount': 11702.229005635598, 'timestamp': 1781843950.7506588}
# Sent: {'tx_id': 50, 'userId': 104, 'amount': 4994.043375335126, 'timestamp': 1781843952.7538626}
# Sent: {'tx_id': 51, 'userId': 103, 'amount': 11212.526896550256, 'timestamp': 1781843954.7547514}
# Sent: {'tx_id': 52, 'userId': 103, 'amount': 7882.795152517157, 'timestamp': 1781843956.7552528}
# Sent: {'tx_id': 53, 'userId': 103, 'amount': 3920.6148881571853, 'timestamp': 1781843958.7556648}
# Sent: {'tx_id': 54, 'userId': 103, 'amount': 14403.83263999974, 'timestamp': 1781843960.7568707}
# Sent: {'tx_id': 55, 'userId': 105, 'amount': 705.6139348452842, 'timestamp': 1781843962.7582688}
# Sent: {'tx_id': 56, 'userId': 103, 'amount': 506.7365831222632, 'timestamp': 1781843964.7594993}
# Sent: {'tx_id': 57, 'userId': 104, 'amount': 6143.484166616008, 'timestamp': 1781843966.7599244}
# Sent: {'tx_id': 58, 'userId': 104, 'amount': 5270.603787603859, 'timestamp': 1781843968.7603867}
# Sent: {'tx_id': 59, 'userId': 105, 'amount': 134.48019678501788, 'timestamp': 1781843970.762182}
# Sent: {'tx_id': 60, 'userId': 103, 'amount': 1759.5849370484125, 'timestamp': 1781843972.763508}
# Sent: {'tx_id': 61, 'userId': 103, 'amount': 606.0709449670369, 'timestamp': 1781843974.7647722}
# Sent: {'tx_id': 62, 'userId': 104, 'amount': 3342.2023557776924, 'timestamp': 1781843976.765284}
# Sent: {'tx_id': 63, 'userId': 105, 'amount': 2312.4761011660435, 'timestamp': 1781843978.7665334}
# Sent: {'tx_id': 64, 'userId': 105, 'amount': 5207.031410955678, 'timestamp': 1781843980.767857}
# Sent: {'tx_id': 65, 'userId': 102, 'amount': 13423.226909471548, 'timestamp': 1781843982.768492}
# Sent: {'tx_id': 66, 'userId': 103, 'amount': 10490.006756846464, 'timestamp': 1781843984.7689552}
# Sent: {'tx_id': 67, 'userId': 102, 'amount': 9206.306272147269, 'timestamp': 1781843986.77036}
# Sent: {'tx_id': 68, 'userId': 105, 'amount': 13033.113552428202, 'timestamp': 1781843988.7709455}
# Sent: {'tx_id': 69, 'userId': 104, 'amount': 13278.84371382971, 'timestamp': 1781843990.7727551}
# Sent: {'tx_id': 70, 'userId': 103, 'amount': 6246.67843249159, 'timestamp': 1781843992.7739425}
# Sent: {'tx_id': 71, 'userId': 102, 'amount': 13151.463302888424, 'timestamp': 1781843994.775574}
# Sent: {'tx_id': 72, 'userId': 101, 'amount': 6612.559137376096, 'timestamp': 1781843996.776743}
# Sent: {'tx_id': 73, 'userId': 104, 'amount': 14101.059502689257, 'timestamp': 1781843998.7771854}
# Sent: {'tx_id': 74, 'userId': 102, 'amount': 8282.408580771604, 'timestamp': 1781844000.7776146}
# Sent: {'tx_id': 75, 'userId': 105, 'amount': 3081.4247197292825, 'timestamp': 1781844002.7780416}
# Sent: {'tx_id': 76, 'userId': 102, 'amount': 1220.1006244621267, 'timestamp': 1781844004.778616}
# Sent: {'tx_id': 77, 'userId': 101, 'amount': 8414.675595316516, 'timestamp': 1781844006.7848375}
# Sent: {'tx_id': 78, 'userId': 102, 'amount': 11618.259512628665, 'timestamp': 1781844008.7853038}
# Sent: {'tx_id': 79, 'userId': 102, 'amount': 4573.932844892009, 'timestamp': 1781844010.7863555}
# Sent: {'tx_id': 80, 'userId': 105, 'amount': 14349.817888548703, 'timestamp': 1781844012.7867827}
# Sent: {'tx_id': 81, 'userId': 104, 'amount': 4516.9340565460725, 'timestamp': 1781844014.788022}
# Sent: {'tx_id': 82, 'userId': 104, 'amount': 8288.696719802578, 'timestamp': 1781844016.7884295}
# Sent: {'tx_id': 83, 'userId': 104, 'amount': 563.0673033332399, 'timestamp': 1781844018.789626}
# Sent: {'tx_id': 84, 'userId': 101, 'amount': 10361.246113664558, 'timestamp': 1781844020.7901397}
# Sent: {'tx_id': 85, 'userId': 104, 'amount': 11767.014569148236, 'timestamp': 1781844022.79073}
# Sent: {'tx_id': 86, 'userId': 102, 'amount': 3591.374925791737, 'timestamp': 1781844024.7919421}
# Sent: {'tx_id': 87, 'userId': 105, 'amount': 2344.5028397636497, 'timestamp': 1781844026.792592}
# Sent: {'tx_id': 88, 'userId': 101, 'amount': 211.05646030166852, 'timestamp': 1781844028.794413}
# Sent: {'tx_id': 89, 'userId': 101, 'amount': 13254.46201549665, 'timestamp': 1781844030.7961314}
# Sent: {'tx_id': 90, 'userId': 105, 'amount': 6659.251344126249, 'timestamp': 1781844032.7973757}
# Sent: {'tx_id': 91, 'userId': 103, 'amount': 3468.691693533454, 'timestamp': 1781844034.797809}
# Sent: {'tx_id': 92, 'userId': 102, 'amount': 8990.670486049677, 'timestamp': 1781844036.79832}
# Sent: {'tx_id': 93, 'userId': 101, 'amount': 13834.555355347611, 'timestamp': 1781844038.7987785}
# Sent: {'tx_id': 94, 'userId': 101, 'amount': 950.3734332432474, 'timestamp': 1781844040.7992432}
# Sent: {'tx_id': 95, 'userId': 102, 'amount': 8807.641907965297, 'timestamp': 1781844042.7996836}
# Sent: {'tx_id': 96, 'userId': 103, 'amount': 13869.923032800814, 'timestamp': 1781844044.800205}
# Sent: {'tx_id': 97, 'userId': 101, 'amount': 3433.622636521769, 'timestamp': 1781844046.8008149}
# Sent: {'tx_id': 98, 'userId': 102, 'amount': 5695.44310760547, 'timestamp': 1781844048.8020682}
# Sent: {'tx_id': 99, 'userId': 102, 'amount': 10629.413683868805, 'timestamp': 1781844050.8032358}
